# %%
import requests

# %%
resourceGroup = input('Enter Resource Group: ')

URL = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourcegroups/{resourceGroup}?api-version=2021-04-01'.format(resourceGroup = resourceGroup)

data = '''
{
    location: "westeurope"
}'''

headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....Y_PLytN17nua20SuvRHGa8z9c9FutEXSHwVKwGqsUKc6xtNXA-t4J-lvf7MxN8d1rlQwMlHCNaj0RLYc_FG5zrd1472Hl3hqJxCypl-gbnkLLAHmY4Tk8XknL1NSgTm9IHtsHP7ekp-8MR0j8q9pHqUBPE7o_3GK-B3hhcbT53GLe3F7LqUXvoYxyrZqK0V84wKPahCDLyfGxI9RsJar90gAiQmEzHyfmmFbJBBr7c_hiEmtjyzJT-VGvbxAuON64WzNkijSyOUHlBvcLRhFs0b6-siL8UDgDNgTAoIMODkXgckBmzOfdOYzVyAAxtxND1uQfaRM9SQXNOnr6o30bw',
          'Content-type' : 'application/json'}

r = requests.put(url = URL, data = data, headers = headers)

pastebin_url = r.text
print('The pastebin URL is:%s' % pastebin_url)

# %%
#IP

publicIpAddressInput = input('Enter public Ip Address name: ')
resourceGroupInput = input('Enter Resource Group: ')

URL = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Network/publicIPAddresses/{publicIpAddressName}?api-version=2023-05-01'.format(resourceGroupName = resourceGroupInput, publicIpAddressName = publicIpAddressInput)

data = '''
{
  "location": "westeurope"
}'''

headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....Y_PLytN17nua20SuvRHGa8z9c9FutEXSHwVKwGqsUKc6xtNXA-t4J-lvf7MxN8d1rlQwMlHCNaj0RLYc_FG5zrd1472Hl3hqJxCypl-gbnkLLAHmY4Tk8XknL1NSgTm9IHtsHP7ekp-8MR0j8q9pHqUBPE7o_3GK-B3hhcbT53GLe3F7LqUXvoYxyrZqK0V84wKPahCDLyfGxI9RsJar90gAiQmEzHyfmmFbJBBr7c_hiEmtjyzJT-VGvbxAuON64WzNkijSyOUHlBvcLRhFs0b6-siL8UDgDNgTAoIMODkXgckBmzOfdOYzVyAAxtxND1uQfaRM9SQXNOnr6o30bw',
          'Content-type' : 'application/json'}

requestIP = requests.put(url = URL, data = data, headers = headers)

pastebin_url = requestIP.text
print('The pastebin URL is:%s' % pastebin_url)
# Out:
# Enter public Ip Address name: ip4test
# Enter Resource Group: lab4
# The pastebin URL is:{"name":"ip4test","id":"/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/lab4/providers/Microsoft.Network/publicIPAddresses/ip4test","etag":"W/\"4b9392d0-3129-48e2-b71d-64d028599a51\"","location":"westeurope","properties":{"provisioningState":"Updating","resourceGuid":"b57c7fba-ac4c-4c52-ab09-34564239fa8c","publicIPAddressVersion":"IPv4","publicIPAllocationMethod":"Dynamic","idleTimeoutInMinutes":4,"ipTags":[]},"type":"Microsoft.Network/publicIPAddresses","sku":{"name":"Basic","tier":"Regional"}}

# %%
#NIC
#########MUST ASSIGN IP ADDRESS THAT HAS NETWORK AND SUBNET (I THINK?)########
#########Actualy think just have to assign ip that's not already used########

networkInterfaceInput = input('Enter Network Interface Name: ')
resourceGroupInput = input('Enter Resource Group name: ')

URL = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Network/networkInterfaces/{networkInterfaceName}?api-version=2023-05-01'.format(resourceGroupName = resourceGroupInput, networkInterfaceName = networkInterfaceInput)

data = '''
{{
  "properties": {{
    "ipConfigurations": [
      {{
        "name": "ipconfig1",
        "properties": {{
          "publicIPAddress": {{
            "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/publicIPAddresses/ip4test"
          }},
          "subnet": {{
            "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/virtualNetworks/net4/subnets/snet4"
          }}
        }}
      }}
    ]
  }},
  "location": "westeurope"
}}'''.format(resourceGroupName = resourceGroupInput, networkInterfaceName = networkInterfaceInput)

headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....bZfEjT8MqiIIH7GftZ8iR0e8AMo0oKgp_HYzCmesqJ8J0A0j_vOOT6AKrOSNnY0A0p7cJDqC5zYGqz8Yo5qUQhaCPa9QN5AG5RUalR4ysEsAis3wwuhVtpBYAgX8hCdes7FHLvzVUINazFXaBIuvdi7RWmUbdF62uEHDyllY_9eiMGVu5vemu87-gBz5x3jRVbuJUSFtms6wIH7kNVc0ViSQzuPNQdjuzZdecE921Tzwn4PEVUFXlqEQwWNGAO2DyjqUvP3-h7kRyUozQf7LYsxmU_6LwcgZjHdsgpo_hyq8D_h1H8TOK1RRPG_kJYHd1II5mhu-ddfuOP0kHBlyJw',
          'Content-type' : 'application/json'}

requestNIC = requests.put(url = URL, data = data, headers = headers)

pastebin_url = requestNIC.text
print('The pastebin URL is:%s' % pastebin_url)
# Out:
# Enter Network Interface Name: nic4test
# Enter Resource Group name: lab4
# ...

# %%
#VM

######### NIC MUST BE ASSIGNED#########

vmInput = input('Enter VM name: ')
resourceGroupInput = input('Enter Resource Group: ')

URL = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Compute/virtualMachines/{vmName}?api-version=2023-07-01'.format(resourceGroupName = resourceGroupInput, vmName = vmInput)

data = '''
{{
  "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Compute/virtualMachines/{vmName}",
  "type": "Microsoft.Compute/virtualMachines",
  "properties": {{
    "osProfile": {{
      "adminUsername": "dfega",
      "secrets": [
        
      ],
      "computerName": "{vmName}",
      "linuxConfiguration": {{
        "ssh": {{
          "publicKeys": [
            {{
              "path": "/home/dfega/.ssh/authorized_keys",
              "keyData": "ssh-rsa ... dfega@HPLaptop"
            }}
          ]
        }},
        "disablePasswordAuthentication": true
      }}
    }},
    "networkProfile": {{
      "networkInterfaces": [
        {{
          "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/networkInterfaces/nic4test",
          "properties": {{
            "primary": true
          }}
        }}
      ]
    }},
    "storageProfile": {{
      "imageReference": {{
        "sku": "16.04-LTS",
        "publisher": "Canonical",
        "version": "latest",
        "offer": "UbuntuServer"
      }},
      "dataDisks": [
        
      ]
    }},
    "hardwareProfile": {{
      "vmSize": "Standard_D1_v2"
    }},
    "provisioningState": "Creating"
  }},
  "name": "{vmName}",
  "location": "westeurope"
}}'''.format(resourceGroupName = resourceGroupInput, vmName = vmInput)

headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....gEpza990WGuvDTEEMEsCof0Y65lG08XzFIRkQUU5no6pPyLsGWAlSSc-5ZoxfuHBdfFzNZUrxnK-XtRUur_r7jUgwOvCdH-ISDjqdcMGe0FHXnRYJicsjCPJ3ou6hEtSUiGtUl5aEQs1GDGMfxdcHyOaDKSDYIi4hzM2E1017PgzXkT9UCp9Rebda8_xQ1rK9mfq-xL_DO2ABXtEzlT3naTAEg8IuqJpw1MbcmXNsK-KFU4xPJ5lfkpuDwBH3COknD7jMOP65Wb9S6Xz6VuJXiy7zPRe3XslJ0nIMbbnomtYnRC5TIlov7Wp3fYqLPAmKTVvMI7M8D9gHFX3t3vFhg',
          'Content-type' : 'application/json'}

requestVM = requests.put(url = URL, data = data, headers = headers)

pastebin_url = requestVM.text
print('The pastebin URL is:%s' % pastebin_url)
# Out:
# Enter VM name: vm4test
# Enter Resource Group: lab4
# The pastebin URL is:{
#   "name": "vm4test",
#   "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/lab4/providers/Microsoft.Compute/virtualMachines/vm4test",
#   "type": "Microsoft.Compute/virtualMachines",
#   "location": "westeurope",
#   "properties": {
#     "hardwareProfile": {
#       "vmSize": "Standard_D1_v2"
#     },
#     "provisioningState": "Creating",
#     "vmId": "5ecff208-5d1a-4331-8bd8-dbb8e5cd2db6",
#     "storageProfile": {
#       "imageReference": {
#         "publisher": "Canonical",
#         "offer": "UbuntuServer",
#         "sku": "16.04-LTS",
#         "version": "latest",
#         "exactVersion": "16.04.202109280"
#       },
#       "osDisk": {
#         "osType": "Linux",
#         "createOption": "FromImage",
#         "caching": "ReadWrite",
#         "managedDisk": {
#           "storageAccountType": "Standard_LRS"
#         },
#         "deleteOption": "Detach",
# ...

# %%
#IP + NIC + VM

resourceGroupInput = input('Enter Resource Group: ')
#virtualNetworkInput = input('Enter Virtual Network Name')
#virtualNetworkInput = input('Enter Subnet Name')
publicIpAddressInput = input('Enter public Ip Address name: ')
networkInterfaceInput = input('Enter Network Interface Name: ')
vmInput = input('Enter VM name: ')

URLip = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Network/publicIPAddresses/{publicIpAddressName}?api-version=2023-05-01'.format(resourceGroupName = resourceGroupInput, publicIpAddressName = publicIpAddressInput)
dataip = '''
{
  "location": "westeurope"
}'''
headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....O5cD4MagILi5ZCsvCf45fkxX5St7Zp3f_NaADS9mHWHdG_dbbWUo9URzDueRGYJArNKUoLXBXkSzWR2QVM6fbstfRBMKglP8D6VktEylV5jr015htebKYrqzX09f9UiQxuC3oLRgiyxVuijbDNSsiPiYd2R593Vg5A8eklCh30_02fZ04MfGQCEJSxAtnYg17Up9iuEuBEd4QY9n-dkPsY1jbHe9Hq7ePiWcgnEquiFNYbHBYQpgS9oar293Ms_-SePFXA6A2VoV0qkQ4rrF3uD4yOVrXeheX3YSwIyUyuug_5Nq66M3joogKw7oOZhFHDPgsB4WUUnDfaQoh33yjQ',
          'Content-type' : 'application/json'}
requestIP = requests.put(url = URLip, data = dataip, headers = headers)
pastebin_url = requestIP.text
print('The pastebin URL is:%s' % pastebin_url)

#NIC

URLnic = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Network/networkInterfaces/{networkInterfaceName}?api-version=2023-05-01'.format(resourceGroupName = resourceGroupInput, networkInterfaceName = networkInterfaceInput)
datanic = '''
{{
  "properties": {{
    "ipConfigurations": [
      {{
        "name": "ipconfig1",
        "properties": {{
          "publicIPAddress": {{
            "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/publicIPAddresses/ip4test"
          }},
          "subnet": {{
            "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/virtualNetworks/net4/subnets/snet4"
          }}
        }}
      }}
    ]
  }},
  "location": "westeurope"
}}'''.format(resourceGroupName = resourceGroupInput, networkInterfaceName = networkInterfaceInput)
headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....ZWrDXk7-Ns4xfT1dR3gvgI07C3t_4FHvZBucRYiAaZXT1zRnUz_VpCNi48cqpu6EweNzz5Fqv9MkY5lelD7QW07nZUFpvLDqanrPb6PZBW2wXZH1bmwiqkWpPjc8I7fT0VGWMIhqhlvmH8Y8uPuLSj2gyI7U_wls9q0gMDZvIDiPTxdo6y3_VEKw7rLyxLCAco9gD3U_-2yHh9df3ZYVm1YvMZcPHNDn4tWivdtm8xd0nUHvP1VHFA9x7XGwfGsL2UN8XzWWZY4vqNndEQPF33umhe5NfsoIXNYl5OK_PzIAP_PY5x0jg5jTTygcfVOG9ggLZtDTZmys0557ZRRQUQ',
          'Content-type' : 'application/json'}
requestNIC = requests.put(url = URLnic, data = datanic, headers = headers)
pastebin_url = requestNIC.text
print('The pastebin URL is:%s' % pastebin_url)

#VM

######### NIC MUST BE ASSIGNED#########

URLvm = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Compute/virtualMachines/{vmName}?api-version=2023-07-01'.format(resourceGroupName = resourceGroupInput, vmName = vmInput)
datavm = '''
{{
  "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Compute/virtualMachines/{vmName}",
  "type": "Microsoft.Compute/virtualMachines",
  "properties": {{
    "osProfile": {{
      "adminUsername": "dfega",
      "secrets": [
        
      ],
      "computerName": "{vmName}",
      "linuxConfiguration": {{
        "ssh": {{
          "publicKeys": [
            {{
              "path": "/home/dfega/.ssh/authorized_keys",
              "keyData": "ssh-rsa ... dfega@HPLaptop"
            }}
          ]
        }},
        "disablePasswordAuthentication": true
      }}
    }},
    "networkProfile": {{
      "networkInterfaces": [
        {{
          "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/networkInterfaces/nic4test",
          "properties": {{
            "primary": true
          }}
        }}
      ]
    }},
    "storageProfile": {{
      "imageReference": {{
        "sku": "16.04-LTS",
        "publisher": "Canonical",
        "version": "latest",
        "offer": "UbuntuServer"
      }},
      "dataDisks": [
        
      ]
    }},
    "hardwareProfile": {{
      "vmSize": "Standard_D1_v2"
    }},
    "provisioningState": "Creating"
  }},
  "name": "{vmName}",
  "location": "westeurope"
}}'''.format(resourceGroupName = resourceGroupInput, vmName = vmInput)
headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....gEpza990WGuvDTEEMEsCof0Y65lG08XzFIRkQUU5no6pPyLsGWAlSSc-5ZoxfuHBdfFzNZUrxnK-XtRUur_r7jUgwOvCdH-ISDjqdcMGe0FHXnRYJicsjCPJ3ou6hEtSUiGtUl5aEQs1GDGMfxdcHyOaDKSDYIi4hzM2E1017PgzXkT9UCp9Rebda8_xQ1rK9mfq-xL_DO2ABXtEzlT3naTAEg8IuqJpw1MbcmXNsK-KFU4xPJ5lfkpuDwBH3COknD7jMOP65Wb9S6Xz6VuJXiy7zPRe3XslJ0nIMbbnomtYnRC5TIlov7Wp3fYqLPAmKTVvMI7M8D9gHFX3t3vFhg',
          'Content-type' : 'application/json'}
requestVM = requests.put(url = URLvm, data = datavm, headers = headers)
pastebin_url = requestVM.text
print('The pastebin URL is:%s' % pastebin_url)
# Out:
# Enter Resource Group: lab4
# Enter public Ip Address name: ip4test
# Enter Network Interface Name: nic4test
# Enter VM name: vm4test
# The pastebin URL is:{"name":"ip4test","id":"/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/lab4/providers/Microsoft.Network/publicIPAddresses/ip4test","etag":"W/\"1f76a3a1-d126-4557-b5c3-9e72d81ceb88\"","location":"westeurope","properties":{"provisioningState":"Updating","resourceGuid":"1dee1205-2cab-46a9-bcfe-30c9f67f94cc","publicIPAddressVersion":"IPv4","publicIPAllocationMethod":"Dynamic","idleTimeoutInMinutes":4,"ipTags":[]},"type":"Microsoft.Network/publicIPAddresses","sku":{"name":"Basic","tier":"Regional"}}
# ...

# %%
#IP + NIC + VM

resourceGroupInput = input('Enter Resource Group: ')
virtualNetworkInput = input('Enter Virtual Network Name: ')
subnetInput = input('Enter Subnet Name: ')
publicIpAddressInput = input('Enter public Ip Address name: ')
networkInterfaceInput = input('Enter Network Interface Name: ')
vmInput = input('Enter VM name: ')

#IP

URLip = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Network/publicIPAddresses/{publicIpAddressName}?api-version=2023-05-01'.format(resourceGroupName = resourceGroupInput, publicIpAddressName = publicIpAddressInput)
dataip = '''
{
  "location": "westeurope"
}'''
headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....vMvq0JmT-HL2FkQYZUde8UV9AE6OK96omIZYe8F8i-5RlXprpR3WlMN4aLO-zQdUjJuyBNW79xwwKdPyqv5Zal7sWzmXO-cSmIiFura27WLKZxjRV6KJeNLHXJfpan2jsNHzIkP3sOAEvz7GUN1hBv9SQqyCXmygRzVuKoTCCm1opdCh7Xa9FPetmbAoFYUx974hy_09qnE3mYemMzI7119eOUwcPB3-IlfuCiWzgTXrkLQbnoUx9nKiywuatQapHGT_Y8AKjmFnTlS2pDLrfdGJNWG_JTu4RaOxDf_b0K91FWgy8HIc0ppy9Wc1AMJfXP9_i4NkP3AIX2BIZHzSqQ',
          'Content-type' : 'application/json'}
requestIP = requests.put(url = URLip, data = dataip, headers = headers)
pastebin_url = requestIP.text
print('The pastebin URL is:%s' % pastebin_url)

#NIC

URLnic = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Network/networkInterfaces/{networkInterfaceName}?api-version=2023-05-01'.format(resourceGroupName = resourceGroupInput, networkInterfaceName = networkInterfaceInput)
datanic = '''
{{
  "properties": {{
    "ipConfigurations": [
      {{
        "name": "ipconfig1",
        "properties": {{
          "publicIPAddress": {{
            "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/publicIPAddresses/{publicIpAddressName}"
          }},
          "subnet": {{
            "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/virtualNetworks/{virtualNetworkName}/subnets/{subnetName}"
          }}
        }}
      }}
    ]
  }},
  "location": "westeurope"
}}'''.format(resourceGroupName = resourceGroupInput, networkInterfaceName = networkInterfaceInput, publicIpAddressName = publicIpAddressInput, virtualNetworkName = virtualNetworkInput, subnetName = subnetInput)
headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....mJIk3vhk7U2GhBiqDNjzUlsCN2ROpy4YkP3vVFj-RVv38hiIiZJ--lpwWdR-v2PlDbcIvfYAkroJJgwL4cx5ncj8cWEzZQ_jiuJ06zyFFZokgTaLla5-8FxdWVSuXpqoFabTHIOr8gWpfpsuPfG_RU9QvH-RNnGgsB7vb6oNWB2EN-GJH5kDKqX4RuHtAHWeGS-4ztk1gwnIK4Ns3Cv1h5TR66wMvy1vmR1bsfJW85__vhnsXSibJUTLyO0HQYbgf1Srxxx-ipXM8-Kpu8KaeKLvSdL7N0YzG83YpP7taiwHc7EXT_iGLj7vIx1XQif_fSj0nSAJBbwzbvpMBDS4Ig',
          'Content-type' : 'application/json'}
requestNIC = requests.put(url = URLnic, data = datanic, headers = headers)
pastebin_url = requestNIC.text
print('The pastebin URL is:%s' % pastebin_url)

#VM

URLvm = 'https://management.azure.com/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/providers/Microsoft.Compute/virtualMachines/{vmName}?api-version=2023-07-01'.format(resourceGroupName = resourceGroupInput, vmName = vmInput)
datavm = '''
{{
  "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Compute/virtualMachines/{vmName}",
  "type": "Microsoft.Compute/virtualMachines",
  "properties": {{
    "osProfile": {{
      "adminUsername": "dfega",
      "secrets": [
        
      ],
      "computerName": "{vmName}",
      "linuxConfiguration": {{
        "ssh": {{
          "publicKeys": [
            {{
              "path": "/home/dfega/.ssh/authorized_keys",
              "keyData": "ssh-rsa ... dfega@HPLaptop"
            }}
          ]
        }},
        "disablePasswordAuthentication": true
      }}
    }},
    "networkProfile": {{
      "networkInterfaces": [
        {{
          "id": "/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/{resourceGroupName}/ providers/Microsoft.Network/networkInterfaces/{networkInterfaceName}",
          "properties": {{
            "primary": true
          }}
        }}
      ]
    }},
    "storageProfile": {{
      "imageReference": {{
        "sku": "16.04-LTS",
        "publisher": "Canonical",
        "version": "latest",
        "offer": "UbuntuServer"
      }},
      "dataDisks": [
        
      ]
    }},
    "hardwareProfile": {{
      "vmSize": "Standard_D1_v2"
    }},
    "provisioningState": "Creating"
  }},
  "name": "{vmName}",
  "location": "westeurope"
}}'''.format(resourceGroupName = resourceGroupInput, vmName = vmInput, networkInterfaceName = networkInterfaceInput)
headers = {'Authorization' : 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSIsImtpZCI6IjlHbW55RlBraGMzaE91UjIybXZTdmduTG83WSJ9.....uyaulUNUm5lUlpbDut48oEzkMe8vfLBK5xpN1MEQlMfIhQRZuu1q6AdNBGOiCpvPW7kwYl60phiDV_0b-F_L4x8R8Q3yEHf-z-JL6y3c2YaIpLAOPHlOGDKVSPjjC085JPSxyYoXT3YVD3opbeXyvK8i3LMndc80flay7i9E8cpbJZk0WfkVL_6-Z8YZrkt6Gmt28CGoTARA9vOaHx7JLfhbxV9g5oNmxbBgaD4TomtosTU1C3ik81JeKGC5iNHeKtWDvb0AbIESMSMWkIAEKDo0Z7g1Cj3nyWqSsERKKA6BojdQWlGgVtY0D8momOtoi3i9zjV1g2BTlrHeHB_P_A',
          'Content-type' : 'application/json'}
requestVM = requests.put(url = URLvm, data = datavm, headers = headers)
pastebin_url = requestVM.text
print('The pastebin URL is:%s' % pastebin_url)
# Out:
# Enter Resource Group: lab4
# Enter Virtual Network Name: net4
# Enter Subnet Name: snet4
# Enter public Ip Address name: ip4TEST
# Enter Network Interface Name: nic4TEST
# Enter VM name: vm4TEST
# The pastebin URL is:{"name":"ip4TEST","id":"/subscriptions/4e79b837-6117-4a59-abe0-505edb64e15d/resourceGroups/lab4/providers/Microsoft.Network/publicIPAddresses/ip4TEST","etag":"W/\"1a1e440d-4d5f-4b22-a6c2-d2e841b9dcc3\"","location":"westeurope","properties":{"provisioningState":"Updating","resourceGuid":"743c4a78-b3c6-4e77-93f5-ff464e0ec14d","publicIPAddressVersion":"IPv4","publicIPAllocationMethod":"Dynamic","idleTimeoutInMinutes":4,"ipTags":[]},"type":"Microsoft.Network/publicIPAddresses","sku":{"name":"Basic","tier":"Regional"}}
# ...
